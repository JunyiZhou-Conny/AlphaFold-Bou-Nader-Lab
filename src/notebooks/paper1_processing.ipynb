# %%
# Check the gene names
import pandas as pd
import requests

# Read Document 1 (assumes an Excel file with a column "Protein" containing gene names)
df1 = pd.read_excel('/Users/conny/Desktop/AlphaFold/Paper 1 data.xlsx', header=1)

# Now you can access the 'Protein' column
protein_column = df1['Protein'].dropna().unique()
print(protein_column)
gene_names = df1['Protein'].dropna().unique()  # unique gene names, drop NaNs if any
# Out:
# ['ABCE1' 'ABCF1' 'ACAT1' 'ACLY' 'ACP1' 'AGPS' 'AHCY' 'AIM1' 'ALDH18A1'
#  'ALYREF' 'ANKHD1' 'ANKRD17' 'AP2A1' 'AP2B1' 'AQR' 'ARHGEF2' 'ASCC3'
#  'ATAD3A' 'ATP2A2' 'ATP5C1' 'ATP5L' 'ATXN2L' 'BCLAF1' 'C14orf166' 'CAD'
#  'CAPRIN1' 'CARM1' 'CCAR2' 'CCNT1' 'CCT2' 'CCT3' 'CCT4' 'CCT5' 'CCT7'
#  'CCT8' 'CDC5L' 'CDC73' 'CHD4' 'CHERP' 'CLINT1' 'CLTC' 'COPA' 'COPB1'
#  'COPB2' 'CPSF7' 'CRYZ' 'CS' 'CSDE1' 'CSNK1A1' 'CSNK2A1' 'CSNK2A2' 'CTPS1'
#  'DAP3' 'DAZAP1' 'DDX1' 'DDX17' 'DDX18' 'DDX23' 'DDX3X' 'DDX49' 'DDX5'
#  'DDX58' 'DDX6' 'DECR1' 'DHX15' 'DHX29' 'DHX30' 'DHX36' 'DHX37' 'DHX38'
#  'DHX9' 'DIMT1' 'DIS3' 'DIS3L' 'DKC1' 'DNAJA2' 'DNAJA3' 'EEF2' 'EIF2A'
#  'EIF2AK2' 'EIF2C2' 'EIF3A' 'EIF3C' 'EIF3D' 'EIF3L' 'EIF3S9' 'EIF4A1'
#  'EIF4G1' 'EIF4G2' 'EL52' 'EMG1' 'EWSR1' 'EXOSC10' 'EXOSC2' 'EXOSC3'
#  'EXOSC4' 'EXOSC6' 'EXOSC9' 'FAM120A' 'FAM62A' 'FAM98A' 'FAM98B' 'FARSLA'
#  'FASN' 'FBL' 'FLII' 'FRG1' 'FUBP1' 'FUS' 'FXR1' 'G3BP1' 'G3BP2' 'GAPDH'
#  'GART' 'GFPT1' 'GNB2L1' 'GNL3' 'GOLGA2' 'HADHB' 'hCG_1994130'
#  'hCG_2032701' 'hCG_27698' 'hCG_30204' 'hCG_31253' 'HDLBP' 'HEATR1'
#  'HNRNPA0' 'HNRNPH1' 'HNRNPM' 'HNRNPUL1' 'HNRPF' 'HSD17B12' 'HSD17B4'
#  'HSP90AB1' 'HSPA14' 'HSPH1' 'HUWE1' 'HYOU1' 'IGF2BP1' 'IGF2BP3' 'ILF2'
#  'ILF3' 'IPO9' 'JTV1' 'KHDRBS1' 'KIF5B' 'KPNA2' 'LARP1' 'LARP4B' 'LARS'
#  'LBR' 'LRPPRC' 'LRRFIP1' 'LSP1' 'LYAR' 'MATR3' 'MBNL1' 'MCM3' 'MCM5'
#  'MCM6' 'METAP2' 'MKI67' 'MOV10' 'MRPS7' 'MS4A1' 'MTDH' 'MTHFD1' 'MTHFD1L'
#  'MX1' 'MYBBP1A' 'MYH9' 'MYL12A' 'MYO1E' 'MYO1G' 'MYO5A' 'MYO6' 'MYO9B'
#  'NAP1L4' 'NAT10' 'NCL' 'NIFK' 'NKRF' 'NOC4L' 'NOL6' 'NONO' 'NOP2' 'NOP58'
#  'NPM1' 'NPM3' 'NSUN5' 'NUFIP2' 'NUP133' 'NUP153' 'NUP155' 'NUP160'
#  'NUP205' 'NUP210' 'NUP214' 'NUP98' 'OAS3' 'PA2G4' 'PABPC1' 'PABPC4'
#  'PDCD11' 'PEG10' 'PFKL' 'PFKP' 'PHGDH' 'PIP4K2A' 'PIP5K1A' 'PLCG2' 'PLD1'
#  'PLEC' 'PLRG1' 'PNO1' 'PNPT1' 'POLD1' 'POLDIP3' 'POLR1A' 'POLR2A'
#  'POLR2B' 'POM121C' 'POP1' 'PPP1CC' 'PRDX5' 'PRIC295' 'PRKDC' 'PRKRA'
#  'PRMT1' 'PRMT5' 'PRPF3' 'PRPF31' 'PRPF4' 'PRPF8' 'PRRC2A' 'PSMD2' 'PSMD3'
#  'PSPC1' 'PTBP1' 'PUM1' 'PWP1' 'PWP2' 'PYCR1' 'RAB7A' 'RANBP2' 'RASAL3'
#  'RAVER1' 'RBBP6' 'RBM10' 'RBM14' 'RBM15' 'RBM27' 'RBM4' 'RBM5' 'RNASEH1'
#  'RNASEH2B' 'RNASEH2C' 'RNF213' 'ROD1' 'RPL10A' 'RPL12' 'RPL13' 'RPL13A'
#  'RPL17' 'RPL23A' 'RPL24' 'RPL26' 'RPL3' 'RPL4' 'RPL5' 'RPL7' 'RPL7A'
#  'RPL9' 'RPRD2' 'RPS10' 'RPS11' 'RPS12' 'RPS14' 'RPS15' 'RPS17' 'RPS19'
#  'RPS2' 'RPS24' 'RPS25' 'RPS3' 'RPS3A' 'RPS4X' 'RPS5' 'RPS6' 'RPS7' 'RPS9'
#  'RTCB' 'SAMD9' 'SART3' 'SCYL2' 'SF1' 'SF3A1' 'SFPQ' 'SFXN1' 'SKIV2L'
#  'SKIV2L2' 'SLC25A12' 'SLC25A6' 'SLIRP' 'SMAP2' 'SMARCA4' 'SMC1A' 'SMC6'
#  'SNC73' 'SND1' 'SNRNP200' 'SNRP70' 'SNRPD1' 'SNRPD2' 'SNW1' 'SON' 'SRP14'
#  'SRP68' 'SRPK1' 'SRSF1' 'STAU1' 'STRAP' 'SUPT16H' 'SUPT5H' 'TAF15' 'TBL3'
#  'TCOF1' 'TCP1' 'TFG' 'TNIK' 'TNRC6B' 'TRA1' 'TRAF1' 'TRIM25' 'TRIP4'
#  'TRMT2A' 'TSR1' 'TTC37' 'TWISTNB' 'U2AF1' 'U2AF2' 'U5-116KD' 'UBAP2L'
#  'UBE1' 'UPF1' 'UPF3B' 'USP10' 'UTP14A' 'WARS' 'WDR3' 'WDR36' 'WDR6'
#  'WIBG' 'XRN1' 'XRN2' 'YBX1' 'YTHDC2' 'YTHDF2' 'YTHDF3' 'ZC3H11A' 'ZC3H15'
#  'ZC3HAV1' 'ZFR' 'ZNF598']

# %%
# Check the protein name
name_column = df1['Description'].dropna().unique()
print(name_column)
# Out:
# ['ATP-binding cassette sub-family E member 1'
#  'ATP-binding cassette sub-family F member 1'
#  'Acetyl-CoA acetyltransferase, mitochondrial' 'ATP-citrate synthase'
#  'Low molecular weight phosphotyrosine protein phosphatase'
#  'Alkyldihydroxyacetonephosphate synthase, peroxisomal'
#  'Adenosylhomocysteinase' 'Absent in melanoma 1 protein'
#  'Delta-1-pyrroline-5-carboxylate synthase' 'THO complex subunit 4'
#  'Ankyrin repeat and KH domain-containing protein 1'
#  'Ankyrin repeat domain-containing protein 17'
#  'AP-2 complex subunit alpha-1' 'AP-2 complex subunit beta'
#  'Intron-binding protein aquarius'
#  'Rho guanine nucleotide exchange factor 2'
#  'Activating signal cointegrator 1 complex subunit 3'
#  'ATPase family AAA domain-containing protein 3A'
#  'Sarcoplasmic/endoplasmic reticulum calcium ATPase 2'
#  'ATP synthase subunit gamma' 'ATP synthase subunit g, mitochondrial'
#  'Ataxin-2-like protein' 'Bcl-2-associated transcription factor 1'
#  'UPF0568 protein C14orf166' 'CAD protein' 'Caprin-1'
#  'Histone-arginine methyltransferase CARM1'
#  'Cell cycle and apoptosis regulator protein 2' 'Cyclin-T1'
#  'T-complex protein 1 subunit beta' 'T-complex protein 1 subunit gamma'
#  'T-complex protein 1 subunit delta' 'T-complex protein 1 subunit epsilon'
#  'T-complex protein 1 subunit eta' 'T-complex protein 1 subunit theta'
#  'Cell division cycle 5-like protein' 'Parafibromin'
#  'Chromodomain-helicase-DNA-binding protein 4'
#  'Calcium homeostasis endoplasmic reticulum protein'
#  'Clathrin interactor 1' 'Clathrin heavy chain 1' 'Coatomer subunit alpha'
#  'Coatomer subunit beta'
#  'Cleavage and polyadenylation specificity factor subunit 7'
#  'Quinone oxidoreductase' 'Citrate synthase'
#  'Cold shock domain-containing protein E1' 'Casein kinase I isoform alpha'
#  'Casein kinase II subunit alpha' 'CTP synthase'
#  '28S ribosomal protein S29, mitochondrial' 'DAZ-associated protein 1'
#  'ATP-dependent RNA helicase DDX1'
#  'Probable ATP-dependent RNA helicase DDX17'
#  'ATP-dependent RNA helicase DDX18'
#  'Probable ATP-dependent RNA helicase DDX23'
#  'ATP-dependent RNA helicase DDX3X'
#  'Probable ATP-dependent RNA helicase DDX49'
#  'Probable ATP-dependent RNA helicase DDX5'
#  'Probable ATP-dependent RNA helicase DDX58'
#  'Probable ATP-dependent RNA helicase DDX6'
#  '2,4-dienoyl-CoA reductase, mitochondrial'
#  'Putative pre-mRNA-splicing factor ATP-dependent RNA helicase DHX15'
#  'ATP-dependent RNA helicase DHX29'
#  'Putative ATP-dependent RNA helicase DHX30'
#  'ATP-dependent RNA helicase DHX36'
#  'Probable ATP-dependent RNA helicase DHX37'
#  'Pre-mRNA-splicing factor ATP-dependent RNA helicase PRP16'
#  'ATP-dependent RNA helicase A' 'Probable dimethyladenosine transferase'
#  'Exosome complex exonuclease RRP44' 'DIS3-like exonuclease 1'
#  'H/ACA ribonucleoprotein complex subunit 4'
#  'DnaJ homolog subfamily A member 2'
#  'DnaJ homolog subfamily A member 3, mitochondrial' 'Elongation factor 2'
#  'Eukaryotic translation initiation factor 2A'
#  'Interferon-induced, double-stranded RNA-activated protein kinase'
#  'Protein argonaute'
#  'Eukaryotic translation initiation factor 3 subunit A'
#  'Eukaryotic translation initiation factor 3 subunit C'
#  'Eukaryotic translation initiation factor 3 subunit D'
#  'Eukaryotic translation initiation factor 3 subunit L'
#  'Eukaryotic translation initiation factor 3 subunit B'
#  'Eukaryotic initiation factor 4A-I'
#  'Eukaryotic translation initiation factor 4 gamma 1'
#  'Eukaryotic translation initiation factor 4 gamma 2'
#  'Heat shock protein HSP 90-alpha'
#  'Ribosomal RNA small subunit methyltransferase NEP1'
#  'RNA-binding protein EWS' 'Exosome component 10'
#  'Exosome complex component RRP4' 'Exosome complex component RRP40'
#  'Exosome complex component RRP41' 'Exosome complex component MTR3'
#  'Exosome complex component RRP45'
#  'Constitutive coactivator of PPAR-gamma-like protein 1'
#  'Extended synaptotagmin-1' 'Protein FAM98A' 'Protein FAM98B'
#  'Phenylalanine--tRNA ligase alpha subunit' 'Fatty acid synthase'
#  'rRNA 2-O-methyltransferase fibrillarin' 'Protein flightless-1 homolog'
#  'Protein FRG1' 'Far upstream element-binding protein 1'
#  'RNA-binding protein FUS'
#  'Fragile X mental retardation syndrome-related protein 1'
#  'Ras GTPase-activating protein-binding protein 1'
#  'Ras GTPase-activating protein-binding protein 2'
#  'Glyceraldehyde-3-phosphate dehydrogenase'
#  'Trifunctional purine biosynthetic protein adenosine-3'
#  'Glutamine--fructose-6-phosphate aminotransferase [isomerizing] 1'
#  'Guanine nucleotide-binding protein subunit beta-2-like 1'
#  'Guanine nucleotide-binding protein-like 3' 'Golgin subfamily A member 2'
#  'Trifunctional enzyme subunit beta, mitochondrial'
#  '40S ribosomal protein S15a'
#  'Dolichyl-diphosphooligosaccharide--protein glycosyltransferase subunit STT3A'
#  'Probable ATP-dependent RNA helicase DDX47' 'Acetyl-CoA carboxylase 1'
#  'Far upstream element-binding protein 3' 'Vigilin'
#  'Heterogeneous nuclear ribonucleoprotein A0'
#  'Heterogeneous nuclear ribonucleoprotein H'
#  'Heterogeneous nuclear ribonucleoprotein M'
#  'Heterogeneous nuclear ribonucleoprotein U-like protein 1'
#  'Heterogeneous nuclear ribonucleoprotein F'
#  'Estradiol 17-beta-dehydrogenase 12'
#  'Peroxisomal multifunctional enzyme type 2'
#  'Heat shock protein HSP 90-beta' 'Heat shock 70 kDa protein 14'
#  'Heat shock protein 105 kDa' 'E3 ubiquitin-protein ligase HUWE1'
#  'Hypoxia up-regulated protein 1'
#  'Insulin-like growth factor 2 mRNA-binding protein 1'
#  'Insulin-like growth factor 2 mRNA-binding protein 3'
#  'Interleukin enhancer-binding factor 2'
#  'Interleukin enhancer-binding factor 3' 'Importin-9'
#  'Aminoacyl tRNA synthase complex-interacting multifunctional protein 2'
#  'KH domain-containing, RNA-binding, signal transduction-associated protein 1'
#  'Tyrosine-protein kinase receptor' 'Importin subunit alpha'
#  'La-related protein 1' 'La-related protein 4B'
#  'Leucine--tRNA ligase, cytoplasmic' 'Lamin-B receptor'
#  'Leucine-rich PPR motif-containing protein, mitochondrial'
#  'Leucine-rich repeat flightless-interacting protein 1'
#  'Lymphocyte-specific protein 1'
#  'Cell growth-regulating nucleolar protein' 'Matrin-3'
#  'Muscleblind-like protein 1' 'DNA replication licensing factor MCM3'
#  'DNA replication licensing factor MCM5'
#  'DNA replication licensing factor MCM6' 'Methionine aminopeptidase 2'
#  'Antigen KI-67' 'Putative helicase MOV-10'
#  '28S ribosomal protein S7, mitochondrial' 'B-lymphocyte antigen CD20'
#  'Protein LYRIC' 'C-1-tetrahydrofolate synthase, cytoplasmic'
#  'Monofunctional C1-tetrahydrofolate synthase, mitochondrial'
#  'Interferon-induced GTP-binding protein Mx1' 'Myb-binding protein 1A'
#  'Myosin-9' 'Myosin regulatory light chain 12A' 'Unconventional myosin-Ie'
#  'Unconventional myosin-Ig' 'Unconventional myosin-Va'
#  'Unconventional myosin-VI' 'Unconventional myosin-IXb'
#  'Nucleosome assembly protein 1-like 4' 'N-acetyltransferase 10'
#  'Nucleolin' 'MKI67 FHA domain-interacting nucleolar phosphoprotein'
#  'NF-kappa-B-repressing factor' 'Nucleolar complex protein 4 homolog'
#  'Nucleolar protein 6' 'Non-POU domain-containing octamer-binding protein'
#  'Probable 28S rRNA (cytosine(4447)-C(5))-methyltransferase'
#  'Nucleolar protein 58' 'Nucleophosmin' 'Nucleoplasmin-3'
#  'Probable 28S rRNA (cytosine-C(5))-methyltransferase'
#  'Nuclear fragile X mental retardation-interacting protein 2'
#  'Nuclear pore complex protein Nup133'
#  'Nuclear pore complex protein Nup153'
#  'Nuclear pore complex protein Nup155'
#  'Nuclear pore complex protein Nup160'
#  'Nuclear pore complex protein Nup205'
#  'Nuclear pore membrane glycoprotein 210'
#  'Nuclear pore complex protein Nup214'
#  'Nuclear pore complex protein Nup98-Nup96'
#  '2-5-oligoadenylate synthase 3' 'Proliferation-associated protein 2G4'
#  'Polyadenylate-binding protein 1' 'Polyadenylate-binding protein 4'
#  'Protein RRP5 homolog' 'Retrotransposon-derived protein PEG10'
#  'ATP-dependent 6-phosphofructokinase, liver type'
#  'ATP-dependent 6-phosphofructokinase, platelet type'
#  'D-3-phosphoglycerate dehydrogenase'
#  'Phosphatidylinositol 5-phosphate 4-kinase type-2 alpha'
#  'Phosphatidylinositol 4-phosphate 5-kinase type-1 alpha'
#  '1-phosphatidylinositol 4,5-bisphosphate phosphodiesterase gamma-2'
#  'Phospholipase D1' 'Plectin' 'Pleiotropic regulator 1'
#  'RNA-binding protein PNO1'
#  'Polyribonucleotide nucleotidyltransferase 1, mitochondrial'
#  'DNA polymerase' 'Polymerase delta-interacting protein 3'
#  'DNA-directed RNA polymerase I subunit RPA1'
#  'DNA-directed RNA polymerase II subunit RPB1'
#  'DNA-directed RNA polymerase'
#  'Nuclear envelope pore membrane protein POM 121C'
#  'Ribonucleases P/MRP protein subunit POP1'
#  'Serine/threonine-protein phosphatase' 'Peroxiredoxin-5, mitochondrial'
#  'Translational activator GCN1'
#  'DNA-dependent protein kinase catalytic subunit'
#  'Interferon-inducible double-stranded RNA-dependent protein kinase activator A'
#  'Protein arginine N-methyltransferase 1'
#  'Protein arginine N-methyltransferase 5'
#  'U4/U6 small nuclear ribonucleoprotein Prp3'
#  'U4/U6 small nuclear ribonucleoprotein Prp31'
#  'U4/U6 small nuclear ribonucleoprotein Prp4'
#  'Pre-mRNA-processing-splicing factor 8' 'Protein PRRC2A'
#  '26S proteasome non-ATPase regulatory subunit 2'
#  '26S proteasome non-ATPase regulatory subunit 3'
#  'Paraspeckle component 1' 'Polypyrimidine tract-binding protein 1'
#  'Pumilio homolog 1' 'Periodic tryptophan protein 1 homolog'
#  'Periodic tryptophan protein 2 homolog'
#  'Pyrroline-5-carboxylate reductase' 'Ras-related protein Rab-7a'
#  'E3 SUMO-protein ligase RanBP2' 'RAS protein activator like-3'
#  'Ribonucleoprotein PTB-binding 1' 'E3 ubiquitin-protein ligase RBBP6'
#  'RNA-binding protein 10' 'RNA-binding protein 14'
#  'Putative RNA-binding protein 15' 'RNA-binding protein 27'
#  'RNA-binding protein 4' 'RNA-binding protein 5' 'Ribonuclease H1'
#  'Ribonuclease H2 subunit B' 'Ribonuclease H2 subunit C'
#  'E3 ubiquitin-protein ligase RNF213'
#  'Polypyrimidine tract-binding protein 3' '60S ribosomal protein L10a'
#  '60S ribosomal protein L12' '60S ribosomal protein L13'
#  '60S ribosomal protein L13a' '60S ribosomal protein L17'
#  '60S ribosomal protein L23a' '60S ribosomal protein L24'
#  '60S ribosomal protein L26-like 1' '60S ribosomal protein L3'
#  '60S ribosomal protein L4' '60S ribosomal protein L5'
#  '60S ribosomal protein L7' '60S ribosomal protein L7a'
#  '60S ribosomal protein L9'
#  'Regulation of nuclear pre-mRNA domain-containing protein 2'
#  '40S ribosomal protein S10' '40S ribosomal protein S11'
#  '40S ribosomal protein S12' '40S ribosomal protein S14'
#  '40S ribosomal protein S15' '40S ribosomal protein S17'
#  '40S ribosomal protein S19' '40S ribosomal protein S2'
#  '40S ribosomal protein S24' '40S ribosomal protein S25'
#  '40S ribosomal protein S3' '40S ribosomal protein S3a'
#  '40S ribosomal protein S4' '40S ribosomal protein S5'
#  '40S ribosomal protein S6' '40S ribosomal protein S7'
#  '40S ribosomal protein S9' 'tRNA-splicing ligase RtcB homolog'
#  'Sterile alpha motif domain-containing protein 9'
#  'Squamous cell carcinoma antigen recognized by T-cells 3'
#  'SCY1-like protein 2' 'Splicing factor 1' 'Splicing factor 3A subunit 1'
#  'Splicing factor, proline- and glutamine-rich' 'Sideroflexin-1'
#  'Helicase SKI2W' 'Superkiller viralicidic activity 2-like 2'
#  'Calcium-binding mitochondrial carrier protein Aralar1'
#  'ADP/ATP translocase 3'
#  'SRA stem-loop-interacting RNA-binding protein, mitochondrial'
#  'Stromal membrane-associated protein 2' 'Transcription activator BRG1'
#  'Structural maintenance of chromosomes protein 1A'
#  'Structural maintenance of chromosomes protein 6'
#  'Ig alpha-1 chain C region'
#  'Staphylococcal nuclease domain-containing protein 1'
#  'U5 small nuclear ribonucleoprotein 200 kDa helicase'
#  'U1 small nuclear ribonucleoprotein 70 kDa'
#  'Small nuclear ribonucleoprotein Sm D1'
#  'Small nuclear ribonucleoprotein Sm D2' 'SNW domain-containing protein 1'
#  'Protein SON' 'Signal recognition particle 14 kDa protein'
#  'Signal recognition particle subunit SRP68' 'SRSF protein kinase 1'
#  'Serine/arginine-rich splicing factor 1'
#  'Double-stranded RNA-binding protein Staufen homolog 1'
#  'Serine-threonine kinase receptor-associated protein'
#  'FACT complex subunit SPT16' 'Transcription elongation factor SPT5'
#  'TATA-binding protein-associated factor 2N'
#  'Transducin beta-like protein 3' 'Treacle protein'
#  'T-complex protein 1 subunit alpha' 'Protein TFG'
#  'TRAF2 and NCK-interacting protein kinase'
#  'Trinucleotide repeat-containing gene 6B protein' 'Endoplasmin'
#  'TNF receptor-associated factor 1' 'E3 ubiquitin/ISG15 ligase TRIM25'
#  'Activating signal cointegrator 1'
#  'tRNA (uracil-5-)-methyltransferase homolog A'
#  'Pre-rRNA-processing protein TSR1 homolog'
#  'Tetratricopeptide repeat protein 37'
#  'DNA-directed RNA polymerase I subunit RPA43'
#  'Splicing factor U2AF 35 kDa subunit'
#  'Splicing factor U2AF 65 kDa subunit'
#  '116 kDa U5 small nuclear ribonucleoprotein component'
#  'Ubiquitin-associated protein 2-like'
#  'Ubiquitin-like modifier-activating enzyme 1'
#  'Regulator of nonsense transcripts 1'
#  'Regulator of nonsense transcripts 3B'
#  'Ubiquitin carboxyl-terminal hydrolase 10'
#  'U3 small nucleolar RNA-associated protein 14 homolog A'
#  'Tryptophan--tRNA ligase, cytoplasmic' 'WD repeat-containing protein 3'
#  'WD repeat-containing protein 36' 'WD repeat-containing protein 6'
#  'Partner of Y14 and mago' '5-3 exoribonuclease 1' '5-3 exoribonuclease 2'
#  'Nuclease-sensitive element-binding protein 1'
#  'Probable ATP-dependent RNA helicase YTHDC2'
#  'YTH domain-containing family protein 2'
#  'YTH domain-containing family protein 3'
#  'Zinc finger CCCH domain-containing protein 11A'
#  'Zinc finger CCCH domain-containing protein 15'
#  'Zinc finger CCCH-type antiviral protein 1'
#  'Zinc finger RNA-binding protein' 'Zinc finger protein 598']

# %%
import requests
import pandas as pd

# Example list of (gene, description) pairs
gene_desc_list = [
    ("ABCE1", "ATP-binding cassette sub-family E member 1"),
    ("ZNF598", "Zinc finger protein 598"),
    # Add more (gene, description) pairs as needed
]

organism = "9606"
results_dict = {}
rows = []
for gene, description in gene_desc_list:
    query = f'gene_exact:{gene} AND protein_name:"{description}" AND organism_id:{organism}'
    url = "https://rest.uniprot.org/uniprotkb/search"
    params = {
        "query": query,
        "fields": "accession,gene_names,protein_name,organism_name,sequence",
        "format": "json",
        "size": 500
    }
    res = requests.get(url, params=params)
    data = res.json()
    accessions = [r.get("primaryAccession") for r in data.get("results", [])]
    rows.append({
        "gene": gene,
        "accessions": ",".join(accessions) if accessions else "NOT_FOUND",
        "count": len(accessions)
    })

df = pd.DataFrame(rows)
df.to_csv("gene_accessions.csv", index=False)
print("Saved to gene_accessions.csv")
# Out:
# Saved to gene_accessions.csv

# %%
import requests
import pandas as pd
from tqdm import tqdm

df1 = pd.read_excel('/Users/conny/Desktop/AlphaFold/Paper 1 data.xlsx', header=1)
df1 = df1.dropna(subset=['Protein', 'Description'])
gene_desc_list = list(zip(df1['Protein'], df1['Description']))

organism = "9606"
rows = []
failed = []

for gene, description in tqdm(gene_desc_list, desc="Querying UniProt"):
    query = f'gene_exact:{gene} AND protein_name:"{description}" AND organism_id:{organism}'
    url = "https://rest.uniprot.org/uniprotkb/search"
    params = {
        "query": query,
        "fields": "accession,gene_names,protein_name,organism_name,sequence",
        "format": "json",
        "size": 500
    }
    try:
        res = requests.get(url, params=params, timeout=30)
        data = res.json()
        accessions = [r.get("primaryAccession") for r in data.get("results", [])]
        rows.append({
            "gene": gene,
            "description": description,
            "accessions": ",".join(accessions) if accessions else "NOT_FOUND",
            "count": len(accessions)
        })
        if not accessions:
            failed.append((gene, description))
    except Exception as e:
        rows.append({
            "gene": gene,
            "description": description,
            "accessions": "ERROR",
            "count": 0
        })
        failed.append((gene, description))
        print(f"Error for {gene}: {e}")

df = pd.DataFrame(rows)
df.to_csv("gene_accessions.csv", index=False)
print("Saved to gene_accessions.csv")

if failed:
    print("\nFailed queries:")
    for gene, description in failed:
        print(f"{gene}: {description}")
else:
    print("All queries succeeded!")
# Out:
# Querying UniProt: 100%|██████████| 363/363 [02:44<00:00,  2.21it/s]
# Saved to gene_accessions.csv
#
# Failed queries:
# AQR: Intron-binding protein aquarius
# ATP5C1: ATP synthase subunit gamma
# ATP5L: ATP synthase subunit g, mitochondrial
# C14orf166: UPF0568 protein C14orf166
# DDX58: Probable ATP-dependent RNA helicase DDX58
# DECR1: 2,4-dienoyl-CoA reductase, mitochondrial
# DHX15: Putative pre-mRNA-splicing factor ATP-dependent RNA helicase DHX15
# DHX30: Putative ATP-dependent RNA helicase DHX30
# DHX36: ATP-dependent RNA helicase DHX36
# DIMT1: Probable dimethyladenosine transferase
# DKC1: H/ACA ribonucleoprotein complex subunit 4
# EL52: Heat shock protein HSP 90-alpha
# hCG_2032701: Dolichyl-diphosphooligosaccharide--protein glycosyltransferase subunit STT3A
# hCG_27698: Probable ATP-dependent RNA helicase DDX47
# hCG_30204: Acetyl-CoA carboxylase 1
# hCG_31253: Far upstream element-binding protein 3
# KIF5B: Tyrosine-protein kinase receptor
# MOV10: Putative helicase MOV-10
# NOP2: Probable 28S rRNA (cytosine(4447)-C(5))-methyltransferase
# NSUN5: Probable 28S rRNA (cytosine-C(5))-methyltransferase
# NUFIP2: Nuclear fragile X mental retardation-interacting protein 2
# PRIC295: Translational activator GCN1
# RBM15: Putative RNA-binding protein 15
# RPL26: 60S ribosomal protein L26-like 1
# RTCB: tRNA-splicing ligase RtcB homolog
# SKIV2L: Helicase SKI2W
# SNC73: Ig alpha-1 chain C region
# YTHDC2: Probable ATP-dependent RNA helicase YTHDC2

# %%
if failed:
    print("\nFailed queries:")
    for gene, description in failed:
        print(f"{gene}: {description}")
    # Save failed queries to a CSV file
    failed_df = pd.DataFrame(failed, columns=["gene", "description"])
    failed_df.to_csv("failed_gene_accessions.csv", index=False)
    print("Saved failed queries to failed_gene_accessions.csv")
else:
    print("All queries succeeded!")
# Out:
# Failed queries:
# AQR: Intron-binding protein aquarius
# ATP5C1: ATP synthase subunit gamma
# ATP5L: ATP synthase subunit g, mitochondrial
# C14orf166: UPF0568 protein C14orf166
# DDX58: Probable ATP-dependent RNA helicase DDX58
# DECR1: 2,4-dienoyl-CoA reductase, mitochondrial
# DHX15: Putative pre-mRNA-splicing factor ATP-dependent RNA helicase DHX15
# DHX30: Putative ATP-dependent RNA helicase DHX30
# DHX36: ATP-dependent RNA helicase DHX36
# DIMT1: Probable dimethyladenosine transferase
# DKC1: H/ACA ribonucleoprotein complex subunit 4
# EL52: Heat shock protein HSP 90-alpha
# hCG_2032701: Dolichyl-diphosphooligosaccharide--protein glycosyltransferase subunit STT3A
# hCG_27698: Probable ATP-dependent RNA helicase DDX47
# hCG_30204: Acetyl-CoA carboxylase 1
# hCG_31253: Far upstream element-binding protein 3
# KIF5B: Tyrosine-protein kinase receptor
# MOV10: Putative helicase MOV-10
# NOP2: Probable 28S rRNA (cytosine(4447)-C(5))-methyltransferase
# NSUN5: Probable 28S rRNA (cytosine-C(5))-methyltransferase
# NUFIP2: Nuclear fragile X mental retardation-interacting protein 2
# PRIC295: Translational activator GCN1
# RBM15: Putative RNA-binding protein 15
# RPL26: 60S ribosomal protein L26-like 1
# RTCB: tRNA-splicing ligase RtcB homolog
# SKIV2L: Helicase SKI2W
# SNC73: Ig alpha-1 chain C region
# YTHDC2: Probable ATP-dependent RNA helicase YTHDC2
# Saved failed queries to failed_gene_accessions.csv

# %%
import pandas as pd
import requests

# Read the CSV with accessions
df = pd.read_csv("/Users/conny/Desktop/AlphaFold/src/notebooks/p1_gene_accessions.csv")

# Collect all unique accessions (skip NOT_FOUND and empty)
accession_set = set()
for acc_str in df['accessions']:
    if acc_str and acc_str != "NOT_FOUND":
        for acc in acc_str.split(","):
            acc = acc.strip()
            if acc:
                accession_set.add(acc)

print(accession_set)
# Out:
# {'Q14157', 'O43172', 'C9JHP4', 'A0A087WYY5', 'H0Y932', 'A0A5F9ZI66', 'Q14739', 'E5RJB9', 'F8W1S4', 'Q04637', 'A0A2R8Y4S2', 'Q15233', 'M0QY96', 'D6R991', 'D6RBK5', 'F8VQZ7', 'D6RAE9', 'D6REK4', 'Q9Y5B9', 'Q8WWM7', 'Q8NI61', 'P50991', 'P61247', 'O75569', 'Q8TDP1', 'H0YD77', 'P19105', 'K7ERG4', 'H0Y5H6', 'Q9Y4I1', 'B7Z4B8', 'A0A8V8TMA4', 'A0A2R8Y7H1', 'B5BUH5', 'Q9BRP8', 'A6PW58', 'P49790', 'A0A6Q8PH84', 'E9PM36', 'Q7Z2W4', 'Q5T7N0', 'Q9NQT5', 'K7ERM6', 'A0A2R8YDW2', 'A0A2R8Y6G9', 'E9PKT8', 'Q96EP5', 'Q13310', 'P62847', 'A2A3R5', 'A0A2R8Y7I0', 'A0A7I2V351', 'A0A2R8Y7M9', 'J3QLK9', 'A4D210', 'A0A2R8Y459', 'F8VTT8', 'B4DJV5', 'P25398', 'F8WD15', 'P62314', 'A0A7I2YQE1', 'R4GNJ2', 'H0YIC4', 'A0A2R8Y6L3', 'K7EM56', 'A0A286YFA2', 'O15226', 'V9HW96', 'A0A0A0MRL0', 'A0AAQ5BH61', 'Q15020', 'E9PI21', 'Q9BWF3', 'P36578', 'Q13610', 'C9JXK0', 'H0YD99', 'M0R2T0', 'Q9NYF8', 'P48634', 'B2R4W8', 'A0A3B3IRQ8', 'Q9NRX1', 'E9PDU5', 'H0YE22', 'Q9H9B4', 'K7EQA8', 'P52272', 'C9J8S3', 'Q86V81', 'Q9UKE5', 'Q8IWZ3', 'F8WBV7', 'F8W4S1', 'D3DTW3', 'M0QX12', 'A0A5F9ZHJ7', 'A0A3S6H7K8', 'H7C044', 'Q9P2N5', 'A0A0A0MRM8', 'H0YEC5', 'A0A3Q8AM22', 'I3L311', 'B5MCW2', 'P39019', 'P35606', 'E9PL09', 'M0R0N3', 'Q5T8U2', 'A0A7I2V349', 'H0YBN4', 'Q9UN86', 'Q96AE4', 'H7C5R5', 'D6RE04', 'D6RE02', 'H0Y7E6', 'A0A3S6H7G3', 'B3KM87', 'Q7Z739', 'A0A0S2Z541', 'H7BZC3', 'A0A8V8TKT4', 'K7EKY0', 'Q6PKG0', 'F8VRI6', 'Q32MZ4', 'A0A3S6H8B5', 'Q5T1Z4', 'A0A0D9SGB5', 'H0Y8T4', 'O75390', 'C9J2Y9', 'Q24JU4', 'M0R0R2', 'A0A6Q8PG29', 'C9J4V0', 'A0A514C937', 'Q13151', 'P11836', 'A0A8Q3WL40', 'H7C561', 'D6RDG7', 'Q86YV0', 'A0A3S6H8A6', 'A0A286YFM8', 'V9GYD1', 'F8WC79', 'P25205', 'P49792', 'O95793', 'A0A1B0GTR5', 'V9GZ78', 'E9PSF8', 'Q14820', 'Q92598', 'C9JJ13', 'E9PCA1', 'A0A286YF78', 'E7EX73', 'Q00610', 'C9JDV1', 'B7Z982', 'O43242', 'J3KTA8', 'Q96QL0', 'Q8N5L9', 'J3KS65', 'A0A3Q8APY3', 'F8W726', 'Q9BZI7', 'P62750', 'K7ELC2', 'P50579', 'D6RB98', 'A0A7I2V2L9', 'Q8IY37', 'H0YEN4', 'A0A3Q8BCJ2', 'C9J6B6', 'A0A3S6H765', 'X6R6Z1', 'Q01844', 'E5RGC4', 'B7ZAR1', 'A0AAQ5BH34', 'A0A8A5YNG5', 'Q9BY44', 'Q86X55', 'F8VQ14', 'Q6IBM8', 'Q9H0D6', 'Q9Y5A9', 'Q6IN67', 'Q5VU80', 'Q92734', 'A0A0U1RQF0', 'A0A9L9PXE4', 'Q6ZNE1', 'A0A7I2V5M5', 'Q8N5M8', 'H7C3A0', 'O00571', 'Q63HN8', 'F5H596', 'B0QY90', 'A6NP24', 'B1AHB1', 'A0A8V8TPX4', 'P28340', 'H3BPF3', 'J3QLE9', 'Q12965', 'K7EK33', 'A0A7I2V487', 'O60930', 'A0A3Q8B022', 'Q6PK56', 'J3KNJ4', 'C9IY79', 'Q8N451', 'P22087', 'I3L1L3', 'H0YCR0', 'H0Y9J5', 'Q9BVJ6', 'Q9BUV4', 'D6RBZ7', 'A0A6Q8PGR6', 'Q99733', 'B0I1T2', 'A0A2R8YGP2', 'J3KTA4', 'O43395', 'Q9Y2L1', 'D6RAN4', 'A0A3Q8B4M4', 'C9JWH7', 'A0A2R8Y7M7', 'H0YN88', 'Q9BUQ8', 'P61221', 'A0A024R4E5', 'G3V3A4', 'F8W0J2', 'A0A8V8TR21', 'Q6IBR2', 'Q4G1D0', 'K7EJV9', 'Q9NVI7', 'B0QYA5', 'Q14839', 'M0R0Y6', 'J3KSA9', 'Q14677', 'H3BPE4', 'J3KS98', 'P50990', 'P22102', 'Q6I9S2', 'Q9BY77', 'Q15459', 'Q14258', 'H0YAA2', 'A0A075B716', 'Q8WU90', 'H0Y9R4', 'A0A7I2V4G8', 'E7EVX8', 'Q0VGL3', 'K7EJB5', 'Q9NNW5', 'O00116', 'Q96I65', 'A0A8V8TL50', 'B5MCT8', 'Q8IZ69', 'K7EKJ9', 'Q08257', 'A0A087WWH0', 'A0A0S2Z4Y4', 'H0YLA2', 'F8VPA1', 'B4DVU3', 'Q49AJ9', 'H0YEN5', 'D6RFI0', 'O43660', 'H0YDC5', 'O00267', 'Q9BST8', 'A0A494C1T2', 'Q6IPX5', 'F5GZQ3', 'P68400', 'Q9NY85', 'Q6P2R1', 'A0A0B4J210', 'H7C3M2', 'A0A2R8Y6M7', 'H0YC97', 'Q8WU79', 'P08621', 'A0A2R8YEK5', 'Q8IWX8', 'A0A087X2G1', 'E5RJU8', 'K7EQR9', 'Q9BQG0', 'E5RHG7', 'P62851', 'A0A0S2Z491', 'E9PEB5', 'S4R320', 'A0A0U1RRM4', 'H0Y9K7', 'Q9NVP1', 'A0A0G2JRS0', 'A0A9L9PXU0', 'B4DXN6', 'K7ELW5', 'H9KVC3', 'Q6UB35', 'Q15269', 'S4R456', 'Q8N163', 'A0A2R8YE38', 'A0A3B3IRI2', 'Q96P70', 'A0A3B3ITF6', 'E9PNW0', 'E9PKF8', 'H7BXS3', 'A0A2R8YFH6', 'E9PBD8', 'A0A2R8Y795', 'H7C5E4', 'Q9NPD3', 'A0A8Q3SIN5', 'A0A2R8Y7A3', 'P37108', 'C9J556', 'A0A0S2Z4G7', 'A0A7I2V3G5', 'B4DV79', 'A8CG34', 'D6RBF8', 'A2A3R7', 'C9JZI7', 'A0A7I2V699', 'A0A2R8YDP2', 'H0Y394', 'E7EMG9', 'Q14683', 'A0AAQ5BHA8', 'P62841', 'A0AAG2UW87', 'H0YCL3', 'F8WAT3', 'F8VRR3', 'Q9BSJ8', 'A0A7I2V5L3', 'B3KM80', 'Q9BVI4', 'A0AAQ5BH87', ' ...

# %%
import requests
import sys
import json
import pandas as pd
from tqdm import tqdm  # <-- Add this import

# Extract the Protein ID from the column
protein_ids = accession_set

# API Parameters
params = {"fields": ["sequence"]}
headers = {"accept": "application/json"}

# Output file
output_file = "p1_protein_sequences.fasta"

def fetch_sequence(protein_id):
    url = f"https://rest.uniprot.org/uniprotkb/{protein_id}"
    response = requests.get(url, headers=headers, params=params)
    if response.ok:
        data = response.json()
        sequence_info = data.get("sequence", {})
        return sequence_info.get("value", None)
    else:
        print(f"Warning: Failed to fetch {protein_id}", file=sys.stderr)
        return None

results = {}
# Wrap tqdm around the outer loop
for entry in tqdm(protein_ids, desc="Fetching sequences"):
    protein_ids_split = entry.split(";")
    for protein_id in protein_ids_split:
        protein_id = protein_id.strip()
        if protein_id and protein_id not in results:
            sequence = fetch_sequence(protein_id)
            if sequence:
                results[protein_id] = sequence
            else:
                results[protein_id] = "Sequence Not Found"

with open(output_file, "w") as file:
    for protein_id, sequence in results.items():
        file.write(f">{protein_id}\n{sequence}\n")

print(f"Protein sequences saved to {output_file}")
# Out:
# Fetching sequences: 100%|██████████| 1106/1106 [07:35<00:00,  2.43it/s]
# Protein sequences saved to p1_protein_sequences.fasta
